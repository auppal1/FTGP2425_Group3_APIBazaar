# %%
# Import libs
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Approximation of asymptotic pricing function

# supply = token supply
# amount = requested amount of tokens

capacity = 189 # max API capacity
base_price = 100 # starting price for first token
sum_price = 0 # sum of token spot prices
spot_price = 0 # spot price for 1 token on the curve

spot_prices = [] # spot price array
sum_prices = [] # summed spot prices along the curve
supplies = [] # supply array

# point on the curve where we change from constant token price to cubic
step_point = int(capacity * 90/100)

for i in range(capacity):
    supplies.append(i)
    
# token spot prices up to the step point
for amount in range(int(step_point)):
    spot_price = base_price
    spot_prices.append(spot_price)
    sum_price += spot_price
    sum_prices.append(sum_price)
# token spot prices after the step point
for amount in range(capacity - step_point):
    spot_price = (4 * amount**3) + base_price
    spot_prices.append(spot_price)
    sum_price += spot_price
    sum_prices.append(sum_price)

print(len(spot_prices))
print()
print(spot_prices)
print()
print(len(sum_prices))
print()
print(sum_prices)
print()
print(sum_price)
    
plt.figure(figsize=(10, 4))
plt.plot(supplies, spot_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# 189
#
# [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 104, 132, 208, 356, 600, 964, 1472, 2148, 3016, 4100, 5424, 7012, 8888, 11076, 13600, 16484, 19752, 23428]
#
# 189
#
# ...

# %%
plt.figure(figsize=(10, 4))
plt.plot(supplies, sum_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Approximation of asymptotic pricing function
# Trying to calculate/approximate summed prices without using a loop

# supply = token supply
# amount = requested amount of tokens

capacity = 100 # max API capacity
base_price = 100 # starting price for first token

current_price = 0 # current token price
new_price = 0 # price of "current supply + amount"
purchase_price = 0 # purchase price for requested amount
sum_price = 0 # sum of purchase prices

purchase_prices = [] # purchase price array
sum_prices = [] # summed purchase price array
supplies = [] # supply array

# point on the curve where we change from constant token price to cubic
step_point = int(capacity * 90/100)


s = 0
amount = 1

# loop is just to see how this works for different values of current supply
for supply in range(s, capacity):
    if supply + amount <= step_point:
        supplies.append(supply)
        # pricing function for constant portion of curve - doesn't require loop
        purchase_price = base_price * amount
        purchase_prices.append(purchase_price)
        sum_price += purchase_price
        sum_prices.append(sum_price)
    elif supply + amount > step_point and supply + amount < capacity:
        supplies.append(supply)
        # pricing function for cubic portion - doesn't require loop
        # x**4 is integral of 4*x**3
        new_price = (supply + amount - step_point)**4 # should + (base_price * amount) but these cancel
        current_price = (supply - step_point)**4 # + (base_price * amount)
        # add base_price so that cubic portion doesn't start at price=0
        purchase_price = new_price - current_price + base_price
        purchase_prices.append(purchase_price)
        sum_price += purchase_price
        sum_prices.append(sum_price)
    else:
        break


print(len(purchase_prices))
print()
print(purchase_prices)
print()
print(purchase_price)
print()
print(len(sum_prices))
print()
print(sum_prices)
print()
print(sum_price)
    
plt.figure(figsize=(10, 4))
plt.plot(supplies, purchase_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# 99
#
# [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 101, 115, 165, 275, 469, 771, 1205, 1795, 2565]
#
# 2565
#
# 99
#
# ...

# %%
# And if capacity is not a multiple of 10
# See how this compares with solidity and its inability to handle decimals

# supply = token supply
# amount = requested amount of tokens

capacity = 189 # max API capacity
base_price = 100 # starting price for first token

current_price = 0 # current token price
new_price = 0 # price of "current supply + amount"
purchase_price = 0 # purchase price for requested amount
sum_price = 0 # sum of purchase prices

purchase_prices = [] # purchase price array
sum_prices = [] # summed purchase price array
supplies = [] # supply array

# point on the curve where we change from constant token price to cubic
step_point = int(capacity * 90/100)
print(step_point)
print()


s = 0
amount = 1

# loop is just to see how this works for different values of current supply
for supply in range(s, capacity):
    if supply + amount <= step_point:
        supplies.append(supply)
        # pricing function for constant portion of curve - doesn't require loop
        purchase_price = base_price * amount
        purchase_prices.append(purchase_price)
        sum_price += purchase_price
        sum_prices.append(sum_price)
    elif supply + amount > step_point and supply + amount < capacity:
        supplies.append(supply)
        # pricing function for cubic portion - doesn't require loop
        # x**4 is integral of 4*x**3
        new_price = (supply + amount - step_point)**4 # should + (base_price * amount) but these cancel
        current_price = (supply - step_point)**4 # + (base_price * amount)
        # add base_price so that cubic portion doesn't start at price=0
        purchase_price = new_price - current_price + base_price
        purchase_prices.append(purchase_price)
        sum_price += purchase_price
        sum_prices.append(sum_price)
    else:
        break


print(len(purchase_prices))
print()
print(purchase_prices)
print()
print(purchase_price)
print()
print(len(sum_prices))
print()
print(sum_prices)
print()
print(sum_price)
    
plt.figure(figsize=(10, 4))
plt.plot(supplies, purchase_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# 170
#
# 188
#
# [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 101, 115, 165, 275, 469, 771, 1205, 1795, 2565, 3539, 4741, 6195, 7925, 9955, 12309, 15011, 18085, 21555]
#
# 21555
#
# 188
#
# ...

# %%
plt.figure(figsize=(10, 4))
plt.plot(supplies, sum_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# And for selling back down the curve

# supply = token supply
# amount = requested amount of tokens

capacity = 189 # max API capacity
base_price = 100 # starting price for first token

current_price = 0 # current token price
new_price = 0 # price of "current supply - amount"
# difference between current token price and price of "current supply - amount"
sale_price = 0
sum_price = 0 # sum of sale prices

sale_prices = [] # sale price array
sum_prices = [] # summed sale price array
supplies = [] # supply array

# point on the curve where we change from constant token price to cubic
step_point = int(capacity * 90/100)


s = 0
amount = 1

# loop is just to see how this works for different values of current supply
for supply in range(capacity-1, s, -1):
    if supply - amount < step_point and supply - amount >= 0:
        supplies.append(supply)
        # difference between current token price and price of "current supply - amount"
        #sale_price = (base_price * supply) - (base_price * (supply - amount))
        sale_price = base_price * amount
        sale_prices.append(sale_price)
        sum_price += sale_price
        sum_prices.append(sum_price)
    elif supply - amount >= step_point:
        supplies.append(supply)
        current_price = (supply - step_point)**4 # should + (base_price * amount) but these cancel
        new_price = (supply - amount - step_point)**4 # + (base_price * amount) 
        # difference between current token price and price of "current supply - amount"
        # add base_price so that cubic portion doesn't start at price=0
        sale_price = current_price - new_price + base_price
        #sale_price = (supply - amount - step_point)**4 + (base_price * amount)
        sale_prices.append(sale_price)
        sum_price += sale_price
        sum_prices.append(sum_price)
    else:
        break


print(len(sale_prices))
print()
print(sale_prices)
print()
print(sale_price)
print()
print(len(sum_prices))
print()
print(sum_prices)
print()
print(sum_price)
    
plt.figure(figsize=(10, 4))
plt.plot(supplies, sale_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# 188
#
# [21555, 18085, 15011, 12309, 9955, 7925, 6195, 4741, 3539, 2565, 1795, 1205, 771, 469, 275, 165, 115, 101, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]
#
# 100
#
# 188
#
# ...

# %%
plt.figure(figsize=(10, 4))
plt.plot(supplies, sum_prices)
plt.xlabel('Supply')
plt.ylabel('Price')
plt.grid(True)
plt.show()
